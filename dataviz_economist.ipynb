        0.5482206 ,  0.43293719,  0.25251518,  0.59665103,  0.51934437,
        0.60634999,  0.39411433,  0.25878531,  0.56478726,  0.55500324,
        0.56869208,  0.25202323,  0.47364487,  0.39095572,  0.38787561,
        0.39160232,  0.56695716,  0.01606496,  0.59672767,  0.33558735,
        0.6059804 ,  0.26262816,  0.40796194,  0.3771485 ,  0.31390311,
        0.44418094,  0.25247553,  0.41519675,  0.34414588,  0.24983959,
        0.48185391,  0.2060584 ,  0.44687242,  0.25065857,  0.34920057,
        0.4131011 ,  0.32219845,  0.62110601,  0.20322519,  0.52177721,
        0.48318436,  0.50689457,  0.54787384,  0.59284625,  0.39212915,
        0.42318373,  0.20324957,  0.508787  ,  0.42954394,  0.1334819 ,
        0.29024086,  0.20488469,  0.45944102,  0.39396162,  0.49960512,
        0.3645383 ,  0.13690567,  0.46205168,  0.46420147,  0.642773  ,
        0.34846017,  0.63282207,  0.5519496 ,  0.46907687,  0.24062484,
        0.51833733,  0.40129913,  0.26251848,  0.29404811,  0.59022882,
        0.27652738,  0.48410337,  0.80224894,  0.36258806,  0.56750631,
        0.22421628,  0.29982224,  0.30170441,  0.39443198,  0.5127055 ,
        0.45852987,  0.24745242,  0.33649003,  0.24783074,  0.36711327,
        0.42176555,  0.26888297,  0.69552261,  0.38739738,  0.46902166,
        0.29475402,  0.210507  ,  0.34902496,  0.09866205,  0.54218333,
        0.57054564,  0.60948551,  0.34346446,  0.07592782,  0.60161448,
        0.60296966,  0.07756407,  0.52504176,  0.60702845,  0.45916023,
        0.39788971,  0.67622382,  0.66107373,  0.28533789,  0.61357321,
        0.00960489,  0.49662249,  0.42531427,  0.34966293,  0.46904021,
        0.53062215,  0.26046844,  0.43957194,  0.43771852,  0.550203  ,
        0.16812427,  0.20910056, -0.10018685,  0.44173618,  0.36057959,
        0.50417335,  0.38241527,  0.34711042,  0.14561852,  0.34499549,
        0.52298427,  0.32682017,  0.32677321,  0.30992449,  0.42663326,
        0.47807849,  0.20562627,  0.35023293,  0.48520664,  0.12849689,
        0.48336255,  0.43518633,  0.56067588,  0.38139467,  0.4524425 ,
        0.39656862,  0.15618887,  0.25864423,  0.46017818,  0.64376812,
        0.33272068,  0.48312474,  0.25560291,  0.32788379,  0.31965509]

# %%
cm = plt.cm.get_cmap('viridis')
plt.figure(figsize=(6.5,5.5))
fig, ax = plt.subplots(figsize=(6.5,5.5))

# I used WebPlotDigitizer to label each bin
ax.text(-0.098, 3.71, '3.71')
ax.text(-0.03, 8.96, '8.96')
ax.text(0.028, 20.07, '19.07')
ax.text(0.095, 61.77, '61.77')
ax.text(0.17, 97.29, '97.29')
ax.text(0.23, 127.87, '127.87')
ax.text(0.30, 159.07, '159.07')
ax.text(0.38, 171.73, '171.73')
ax.text(0.46, 137.76, '137.76')
ax.text(0.53, 100.69, '100.69')
ax.text(0.60, 78.76, '78.76')
ax.text(0.67, 29.96, '29.96')
ax.text(0.74, 21.31, '19.31')
ax.text(0.82, 5.86, '5.86')

n, bins, patches = plt.hist(sample_hist2, bins=14, edgecolor="grey", linewidth=0.35)
col = (n-n.min())/(n.max()-n.min())

for c, p in zip(col, patches):
    plt.setp(p, 'facecolor', cm(c))
    plt.grid(True, color='0.85')
    ax.set_axisbelow(True)

# %% [markdown]
# #### **Line plot**

# %%
x1 = [1924.367929, 1928.795716, 1932.755804, 1935.780496, 1948.442215, 1952.461894, 1956.879749, 1960.401935, 1964.476691, 1968.859784, 1972.571126,
     1975.984061, 1980.411848, 1988.685508, 1999.087737, 2007.420988, 2010.659665, 2019.445716, 2022.72412]
y1 = [4.444444444,5.925925926,8.148148148,11.85185185,11.2962963,15.74074074,16.85185185,20.92592593,18.33333333,18.14814815,20.18518519,
      20.18518519,21.66666667,21.11111111,36.2962963,37.96296296,40.55555556,40.92592593,45]

# %%
x2 = [1926.572342,1938.0603,1950.269219,1954.0555,1961.951299,1965.926285,1970.080496,1973.672655,1978.548277,1981.687636,1990.229906,
      1999.578911,2011.648784,2017.0219,2019.922443,2023.226129]
y2 = [95.74074074,87.77777778,88.51851852,84.25925926,78.7037037,81.48148148,81.85185185,79.44444444,79.44444444,78.33333333,78.7037037,
      63.7037037,59.25925926,59.62962963,58.7037037,54.62962963]

# %%
fig, ax = plt.subplots(figsize=(5,6))

ax.set_ylim(0, 100)
ax.set_xlim(1920, 2026)

ax.grid(axis='y', color='0.7', clip_on=False)

[ax.spines[spine].set_visible(False) for spine in ax.spines if spine != 'bottom']

ax.set_xticks(np.arange(min(x1), max(x1)+1, 9.5))
ax.set_xticklabels(['1924', '', '40', '', '60', '', '70', '', '2000', '', '22'])

ax.set_title('Participation, %',
    weight='bold', fontsize=10, ha='left', loc='left', pad=24)

ax.text(1975, 30, 'Women', fontweight='bold', color='#1f77b4')
ax.text(1980, 70, 'Men', fontweight='bold', color='#17becf')

plt.draw()

ax.yaxis.tick_right()

ax.tick_params(right=None)

for tick in ax.get_yticklabels():
    tick.set_va('bottom')
    tick.set_ha('right')
    tick.set_x(1)

ax.plot(x1, y1, color='#1f77b4', linewidth=3) # dark blue line
ax.plot(x2, y2, color='#17becf', linewidth=3) # light blue line

# %% [markdown]
# #### **Scatter plot**

# %%
x3 = [1959.22488038277,1961.16267942583,1962.84210526315,1961.03349282296,1961.93779904306,1967.23444976076,1965.55502392344,
      1965.42583732057,1966.45933014354,1970.20574162679,1972.91866028708,1971.36842105263,1972.27272727272,1974.08133971291,
      1975.37320574162,1976.27751196172,1977.95693779904,1976.01913875598,1977.95693779904,1979.37799043062,1979.11961722488,
      1982.0909090909,1982.0909090909,1985.06220095693,1988.93779904306,1988.93779904306,1992.42583732057,1995.78468899521,
      1996.81818181818,1996.81818181818,1998.88516746411,1998.62679425837,1999.66028708133,2002.76076555023,2002.50239234449,
      2005.73205741626,2003.53588516746,2005.60287081339,2005.60287081339,2006.24880382775,2007.7990430622,2006.76555023923,
      2007.41148325358,2009.47846889952,2009.34928229665,2009.34928229665,2010.8995215311]
y4 = [150142689.781431,297445800.524442,1572487329.22575,2166952991.56887,2492865560.92847,1807462411.90496,1956753227.27487,
      2431601664.74957,3143199921.17749,2310280693.05809,2991282496.12205,3377891046.05286,3644456434.40949,3762156944.10198,
      3583405506.58347,3849970894.9401,3967742394.08355,4057828007.35241,4442519842.10729,4501086139.14969,4886984794.5709,
      4736984084.69139,5152414351.71216,5477191089.85639,6098206806.85874,6098206806.85874,6511720358.70357,6658242585.48602,
      6835716212.88724,7132452117.90208,7012621924.68077,7309499808.59753,7605667798.00468,7752332003.68905,8375619383.12213,
      8225476694.3407,8790481734.53522,8522283588.80649,9293796941.84507,8937358908.57246,8906833444.65945,8699686226.75675,
      9292803089.53162,8935584172.29845,9202717476.26277,9410432609.77315,9439254326.86311]

# %%
fig, ax = plt.subplots(figsize=(5,6))

ax.set_ylim(0, 10**10)
ax.set_xlim(1950, 2020)

ax.set_facecolor('lightcyan')

ax.grid(axis='y', color='1', clip_on=False, linewidth=2.5)

[ax.spines[spine].set_visible(False) for spine in ax.spines if spine != 'bottom']

ax.set_xticks(np.arange(min(x3), max(x3)+1, 4.5))
ax.set_xticklabels(['1960', '', '70', '', '80', '', '90', '', '2000', '', '10', '14'], fontsize=12)
ax.set_yticklabels(['1', r'$\ 10^{2}$', r'$\ 10^{4}$', r'$\ 10^{6}$', r'$\ 10^{8}$', r'$\ 10^{10}$'],
                  fontsize=11)

ax.set_title('Always Moore',
    weight='bold', fontsize=15, ha='left', loc='left', pad=60)

ax.set_xlabel('Source: Intel                        *Central processing unit', loc='left', fontsize=11)

ax.axvline(x=1963.798, color='r', ls='--')

ax.text(1965, 10**10, "MOORE'S LAW\nDEFINED", color='red', style='italic', ha='center', fontsize=12)
ax.text(1950, 10**10, "Number of transistors in CPU*\n\n\n", ha='left', fontsize=12)
ax.text(1950, 10**10, "Log scale\n\n\n", ha='left', fontsize=11.35)

plt.draw()

ax.yaxis.tick_right()

ax.tick_params(right=None)

for tick in ax.get_yticklabels():
    tick.set_va('center')
    tick.set_ha('right')
    tick.set_x(1.05)

ax.plot(x3, y3, 'o', color='#069AF3', markersize=8)
# Out:
# C:\Users\alyxm\AppData\Local\Temp/ipykernel_19032/3945663219.py:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['1', r'$\ 10^{2}$', r'$\ 10^{4}$', r'$\ 10^{6}$', r'$\ 10^{8}$', r'$\ 10^{10}$'],

# %% [markdown]
# #### **Bar chart**

# %%
counts = [17.3, 92.5, 50.6, 16.8, 72.5, 49.1, 16.9, 64.7, 48.1]
year = [2009, 2009, 2009, 2015, 2015, 2015, '2019*', '2019*', '2019*']
country = ['World', 'US', 'UK', 'World', 'US', 'UK', 'World', 'US', 'UK']
bar_df = pd.DataFrame(list(zip(counts, year, country)),
              columns=['counts','year', 'country'])
bar_df
# Out:
#    counts   year country
# 0    17.3   2009   World
# 1    92.5   2009      US
# 2    50.6   2009      UK
# 3    16.8   2015   World
# 4    72.5   2015      US
# 5    49.1   2015      UK
# 6    16.9  2019*   World
# 7    64.7  2019*      US
# 8    48.1  2019*      UK

# %%
labels = ['2009', '2015', '2019*']
world_counts = [17.3, 16.8, 16.9]
us_counts = [92.5, 72.5, 64.7]
uk_counts = [50.6, 49.1, 48.1]

x = np.arange(len(labels))  # the label locations
width = 0.3  # the width of the bars

fig, ax = plt.subplots(figsize=(7,5))

ax.set_ylim(0, 115)

rects1 = ax.bar(x - 0.3, world_counts, width, label='World', color='powderblue')
rects2 = ax.bar(x, us_counts, width, label='US', color='skyblue')
rects3 = ax.bar(x + 0.3, uk_counts, width, label='UK', color='#1f77b4')

[ax.spines[spine].set_visible(False) for spine in ax.spines if spine != 'bottom']
ax.set_yticklabels([])
ax.set_yticks([])

ax.set_xlabel('*PROJECTION                                                      SOURCE: EUROMONITOR', ha='center',
             fontsize=12)
ax.set_title('Fizzy cola drinks',
            weight='extra bold', fontsize=15, ha='left', loc='left', pad=14.5, color='#1f77b4') 

ax.text(0.87, 121, "Litres per capita", size=15, color='skyblue', weight='extra bold', ha='center')

plt.xticks(x, labels, fontsize=12)

ax.legend(loc='upper center', ncol=3, frameon=False, fontsize=12)
ax.text(-0.21, 106.55, "Litres per capita   |", size=12, ha='center')

ax.bar_label(rects1, padding=3, color='powderblue', weight='extra bold', fontsize=12)
ax.bar_label(rects2, padding=3, color='skyblue', weight='extra bold', fontsize=12)
ax.bar_label(rects3, padding=3, color='#1f77b4', weight='bold', fontsize=12)

fig.tight_layout()

# %% [markdown]
# #### **Scatter plot matrix**

# %%
import seaborn as sns

# %% [markdown]
# - I decided to create scatter plot matrix with the use of data from my own dataset.
# - This pilot dataset includes information about Final Fantasy XIV players: play time per week, subjective well-being scores, discrimination scores, different motivators to play scores.
# - Data was collected via pilot version of my survey that I placed on a gaming forum.
# - Discription of variables in this dataset is in the file *description.pdf*

# %%
ff14_df = pd.read_csv("ff14.csv")
ff14_df.head()
# Out:
#    time  FF_time  m_soc  m_complet  m_compet  m_esc  m_story  comfeel  disc  \
# 0     3        1    1.0        2.0       2.7    5.0      4.5      2.8   2.3
# 1    18        2    5.0        4.7       3.7    5.0      5.0      4.8   2.0
# 2    25        3    1.3        2.7       1.0    5.0      5.0      3.5   1.5
# 3    20        3    5.0        4.3       3.0    3.5      5.0      4.5   2.0
# 4    15        2    3.7        4.3       2.3    5.0      5.0      4.3   2.3
#
#    swb  gender  age
# 0   23       1   24
# 1   14       2   28
# 2   10       1   40
# 3   28       1   32
# 4   21       1   30

# %%
ff14_df['FF_time'] = ff14_df['FF_time'].apply(lambda x: 'mostly do not play FF14' if x == 1 
                                              else ('play both FF14 and other online games' if x == 2
                                                   else ('mostly play FF14' if x == 3
                                                       else ('only play FF14' if x == 4
                                                            else pd.NA))))
ff14_df['FF_time'].value_counts()
# Out:
# play both FF14 and other online games    21
# mostly play FF14                         15
# mostly do not play FF14                  11
# only play FF14                            4
# Name: FF_time, dtype: int64

# %%
ff_14 = ff14_df[['swb', 'time', 'm_soc', 'm_esc', 'comfeel', 'disc', 'FF_time']]
ff_14['Do you mostly play FF14?'] = ff_14['FF_time']
ff_14.head()
# Out:
# C:\Users\alyxm\AppData\Local\Temp/ipykernel_19032/3560771308.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ff_14['Do you mostly play FF14?'] = ff_14['FF_time']
#    swb  time  m_soc  m_esc  comfeel  disc  \
# 0   23     3    1.0    5.0      2.8   2.3
# 1   14    18    5.0    5.0      4.8   2.0
# 2   10    25    1.3    5.0      3.5   1.5
# 3   28    20    5.0    3.5      4.5   2.0
# 4   21    15    3.7    5.0      4.3   2.3
#
#                                  FF_time  \
# 0                mostly do not play FF14
# 1  play both FF14 and other online games
# 2                       mostly play FF14
# 3                       mostly play FF14
# 4  play both FF14 and other online games
#
#                 Do you mostly play FF14?
# ...

# %%
sns.set_style('ticks')
sns.pairplot(ff_14, hue="Do you mostly play FF14?")
